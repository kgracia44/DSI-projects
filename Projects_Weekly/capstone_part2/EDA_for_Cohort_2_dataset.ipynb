# %%
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
import math
import psycopg2 as psy
from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL

# %%
# %load_ext sql
# %reload_ext sql
# Out:
# /Users/cguy/anaconda/lib/python2.7/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /Users/cguy/anaconda/lib/python2.7/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
# %%sql postgresql://cguy@localhost:5432/nytd_clean_data
#
# SELECT * FROM cohort_2 LIMIT 5;
# Out:
# 5 rows affected.
# [(0L, u'Age 17 Baseline Survey', datetime.datetime(2014, 9, 1, 0, 0), u'participated', datetime.datetime(2014, 5, 14, 0, 0), u'yes', u'no', u'yes', u'no', u'no', u'no', u'no', u'no', u'no', u'no', u'none of the above', u'yes', u'yes', u'no', u'no', u'no', u'no', u'not applicable', u'yes', u'no', u'not applicable', u'not applicable', u'not applicable', u'yes', u'yes', u'yes', u'no', u'Not a Sample State', 1L, u'AL000000227321', 2014L, datetime.datetime(2014, 3, 1, 0, 0), 1L, u'AL', datetime.datetime(1997, 4, 15, 0, 0), 1L, 0L, 0L, 1L, 0L, 0L, 0L, 0L, 0L, 1L, 0L, 0L, 9L, 0L, 0L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 0L, 0L, 0L, 0L, 2L, 2L, u'16'),
#  (1L, u'Age 17 Baseline Survey', datetime.datetime(2014, 9, 1, 0, 0), u'declined', datetime.datetime(1999, 1, 1, 0, 0), u'yes', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'yes', u'no', u'no', u'no', u'Not a Sample State', 0L, u'AL000003716611', 2014L, datetime.datetime(2014, 3, 1, 0, 0), 1L, u'AL', datetime.datetime(1997, 4, 15, 0, 0), 1L, 0L, 0L, 0L, 0L, 1L, 0L, 0L, 0L, 1L, 0L, 0L, 0L, 0L, 0L, 1L, 0L, 0L, 0L, 1L, 1L, 1L, 1L, 1L, 0L, 0L, 0L, 0L, 1L, 1L, u'16'),
#  (2L, u'Age 17 Baseline Survey', datetime.datetime(2014, 9, 1, 0, 0), u'participated', datetime.datetime(2014, 6, 26, 0, 0), u'yes', u'no', u'no', u'no', u'no', u'no', u'no', u'no', u'no', u'no', u'none of the above', u'yes', u'yes', u'no', u'yes', u'no', u'no', u'not applicable', u'yes', u'no', u'not applicable', u'not applicable', u'not applicable', u'yes', u'yes', u'yes', u'no', u'Not a Sample State', 1L, u'AL000008395721', 2014L, datetime.datetime(2014, 3, 1, 0, 0), 1L, u'AL', datetime.datetime(1997, 5, 15, 0, 0), 1L, 0L, 0L, 0L, 0L, 1L, 0L, 0L, 1L, 1L, 0L, 0L, 10L, 0L, 1L, 1L, 1L, 1L, 0L, 1L, 1L, 1L, 1L, 1L, 0L, 0L, 0L, 0L, 1L, 7L, u'16'),
#  (3L, u'Age 17 Baseline Survey', datetime.datetime(2014, 9, 1, 0, 0), u'participated', datetime.datetime(2014, 9, 29, 0, 0), u'yes', u'no', u'no', u'no', u'no', u'no', u'no', u'no', u'no', u'no', u'none of the above', u'yes', u'yes', u'no', u'yes', u'no', u'no', u'not applicable', u'yes', u'no', u'not applicable', u'not applicable', u'not applicable', u'yes', u'yes', u'yes', u'no', u'Not a Sample State', 1L, u'AL000026713423', 2014L, datetime.datetime(2014, 3, 1, 0, 0), 1L, u'AL', datetime.datetime(1997, 9, 15, 0, 0), 2L, 0L, 0L, 0L, 0L, 1L, 0L, 0L, 2L, 1L, 0L, 0L, 7L, 0L, 0L, 1L, 0L, 0L, 0L, 1L, 0L, 1L, 0L, 0L, 1L, 0L, 0L, 0L, 1L, 1L, u'16'),
#  (4L, u'Age 17 Baseline Survey', datetime.datetime(2014, 9, 1, 0, 0), u'declined', datetime.datetime(1999, 1, 1, 0, 0), u'yes', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'blank', u'yes', u'no', u'no', u'no', u'Not a Sample State', 0L, u'AL000030924123', 2014L, datetime.datetime(2014, 3, 1, 0, 0), 1L, u'AL', datetime.datetime(1997, 5, 15, 0, 0), 2L, 0L, 0L, 0L, 0L, 1L, 0L, 0L, 0L, 1L, 0L, 0L, 10L, 1L, 0L, 1L, 0L, 1L, 0L, 1L, 1L, 1L, 1L, 1L, 0L, 0L, 0L, 0L, 1L, 1L, u'16')]
